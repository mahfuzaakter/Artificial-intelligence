# %% [markdown]
# <a href="https://colab.research.google.com/github/mahfuzaakter/Artificial-intelligence/blob/main/day06_machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/download.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=183x275>

# %%
img2 = cv2.imread("/content/download.jpg",0)

# %%
cv2.IMWRITE_JPEG_SAMPLING_FACTOR_420 = cv2.imread("/content/download.jpg",0)

# %%
cv2_imwrite=("gray_scale.jpg", img2)

# %%
img
