# %% [markdown]
# <a href="https://colab.research.google.com/github/mahfuzaakter/Artificial-intelligence/blob/main/day9_image_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 36.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolo11n-seg.pt')

# %%
result = model('/content/busy city.jpg.jpg')
# Out:
# image 1/1 /content/busy city.jpg.jpg: 448x640 4 cars, 3 potted plants, 2 clocks, 60.9ms
# Speed: 13.3ms preprocess, 60.9ms inference, 88.1ms postprocess per image at shape (1, 3, 448, 640)

# %%
result = model.predict(source='/content/busy city.jpg.jpg', save=True)
# Out:
# image 1/1 /content/busy city.jpg.jpg: 448x640 4 cars, 3 potted plants, 2 clocks, 11.6ms
# Speed: 2.7ms preprocess, 11.6ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/segment/predict

# %%
result[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=540x360>

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolo11n-seg.pt')

# %%
model.predict(source='/content/AdobeStock_1595335488_Video_HD_Preview.mov', save=True)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/121) /content/AdobeStock_1595335488_Video_HD_Preview.mov: 384x640 1 bird, 9.6ms
# video 1/1 (frame 2/121) /content/AdobeStock_1595335488_Video_HD_Preview.mov: 384x640 1 bird, 12.0ms
# video 1/1 (frame 3/121) /content/AdobeStock_1595335488_Video_HD_Preview.mov: 384x640 1 bird, 13.3ms
# video 1/1 (frame 4/121) /content/AdobeStock_1595335488_Video_HD_Preview.mov: 384x640 1 bird, 11.3ms
# ...

# %%
vedio = model('/content/AdobeStock_1595335488_Video_HD_Preview.mov', show=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/121) /content/AdobeStock_1595335488_Video_HD_Preview.mov: 384x640 1 bird, 60.5ms
# video 1/1 (frame 2/121) /content/AdobeStock_1595335488_Video_HD_Preview.mov: 384x640 1 bird, 15.4ms
# video 1/1 (frame 3/121) /content/AdobeStock_1595335488_Video_HD_Preview.mov: 384x640 1 bird, 12.4ms
# ...

# %%
model.predict(source='/content/700_F_82523149_zu9wvOHrxvjodBX7uoveSxY5xEJpFBi5_ST.mp4', save=True)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/327) /content/700_F_82523149_zu9wvOHrxvjodBX7uoveSxY5xEJpFBi5_ST.mp4: 384x640 10 persons, 11 cars, 1 bus, 4 trucks, 11.0ms
# video 1/1 (frame 2/327) /content/700_F_82523149_zu9wvOHrxvjodBX7uoveSxY5xEJpFBi5_ST.mp4: 384x640 12 persons, 12 cars, 3 trucks, 8.9ms
# video 1/1 (frame 3/327) /content/700_F_82523149_zu9wvOHrxvjodBX7uoveSxY5xEJpFBi5_ST.mp4: 384x640 12 persons, 11 cars, 2 trucks, 9.0ms
# ...
