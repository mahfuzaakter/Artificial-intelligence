# %% [markdown]
# <a href="https://colab.research.google.com/github/mahfuzaakter/Artificial-intelligence/blob/main/day_python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #variable and datatype

# %%
name="shirin"
age=25
weight=52.7

# %%
name=input("enter your name ")
print(name)
# Out:
# enter your nameshirin
# shirin

# %% [markdown]
# #List

# %%
fruits=['mango','banana','apple']
print(fruits[0])
# Out:
# mango

# %% [markdown]
# #Loop

# %%
for item in fruits:
 print(item)
# Out:
# mango
# banana
# apple

# %% [markdown]
# #condition

# %%
age=18
if age>=18:
  print("you are eligible to vote")
else:
  print("you are not eligible")
# Out:
# you are eligible to vote

# %% [markdown]
# #function

# %%
def greet(name):
    print("hello",name)


    greet('shirin') #function call

# %% [markdown]
# #numpy library

# %%
import numpy as np

# %%
arr1=np.array([1,2,3]) #1-D array
print(arr1)

arr2=np.array([[1,2,3],[4,5,6]]) #2D array
print(arr2)
# Out:
# [1 2 3]
# [[1 2 3]
#  [4 5 6]]

# %%
for row in arr2.flat:
  print(row)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# #pandas library

# %%
import pandas as pd  #dataset creat
data={
    "name":["shirin","setu","sima"],
    "age":["20","21","22"],
    "city":["Dhaka","gazipur","oman"]
}
pd.DataFrame(data)
# Out:
#      name age     city
# 0  shirin  20    Dhaka
# 1    setu  21  gazipur
# 2    sima  22     oman
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('age').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('city').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
# ...

# %% [markdown]
# #matplotlib library

# %%
x=[1,2,3,4,5]
y=[30,40,60,55,75]
import matplotlib.pyplot as plt
plt.plot(x,y)
plt.title("line plot")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %% [markdown]
# #scikit-learn  library for machine learning
#
# load kora, train test split, standard scaler, logistic regression, accuracy score,confusion matrix, classification report
